# %% [markdown]
# <a href="https://colab.research.google.com/github/satyanarayanaallam/tensorflow_practice/blob/main/Dataset_Preprocessing_with_TensorFlow_Transform_(TFT).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Stage 1: Installing dependencies and setting up the environment

# %%
# !pip install tensorflow-transform
# Out:
# Requirement already satisfied: tensorflow-transform in /usr/local/lib/python3.10/dist-packages (1.14.0)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow-transform) (1.4.0)
# Requirement already satisfied: apache-beam[gcp]<3,>=2.47 in /usr/local/lib/python3.10/dist-packages (from tensorflow-transform) (2.54.0)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-transform) (1.24.4)
# Requirement already satisfied: protobuf<5,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-transform) (3.20.3)
# Requirement already satisfied: pyarrow<11,>=10 in /usr/local/lib/python3.10/dist-packages (from tensorflow-transform) (10.0.1)
# Requirement already satisfied: pydot<2,>=1.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-transform) (1.4.2)
# Requirement already satisfied: tensorflow<3,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow-transform) (2.15.0.post1)
# Requirement already satisfied: tensorflow-metadata<1.15.0,>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-transform) (1.14.0)
# Requirement already satisfied: tfx-bsl<1.15.0,>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-transform) (1.14.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (3.9.14)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (1.9.4)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (1.60.1)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.22.0)
# Requirement already satisfied: js2py<1,>=0.74 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.74)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (4.19.2)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (3.0.2)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.7.0)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (23.2)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (4.6.1)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (1.23.0)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.8.2)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2023.4)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2023.12.25)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (4.9.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.22.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.6)
# Requirement already satisfied: cachetools<6,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (5.3.2)
# Requirement already satisfied: google-api-core<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.17.1)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.5.31)
# Requirement already satisfied: google-auth<3,>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.27.0)
# Requirement already satisfied: google-auth-httplib2<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.1.1)
# Requirement already satisfied: google-cloud-datastore<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.15.2)
# Requirement already satisfied: google-cloud-pubsub<3,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.19.4)
# Requirement already satisfied: google-cloud-pubsublite<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (1.9.0)
# Requirement already satisfied: google-cloud-storage<3,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.14.0)
# Requirement already satisfied: google-cloud-bigquery<4,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (3.12.0)
# Requirement already satisfied: google-cloud-bigquery-storage<3,>=2.6.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.24.0)
# Requirement already satisfied: google-cloud-core<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.3.3)
# Requirement already satisfied: google-cloud-bigtable<3,>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.23.0)
# Requirement already satisfied: google-cloud-spanner<4,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (3.42.0)
# Requirement already satisfied: google-cloud-dlp<4,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (3.15.1)
# Requirement already satisfied: google-cloud-language<3,>=2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.9.1)
# Requirement already satisfied: google-cloud-videointelligence<3,>=2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.13.1)
# Requirement already satisfied: google-cloud-vision<4,>=2 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (3.7.0)
# Requirement already satisfied: google-cloud-recommendations-ai<0.11.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.10.8)
# Requirement already satisfied: google-cloud-aiplatform<2.0,>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow-transform) (1.39.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pydot<2,>=1.2->tensorflow-transform) (3.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (2.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (0.36.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow-transform) (2.15.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata<1.15.0,>=1.14.0->tensorflow-transform) (1.62.0)
# Requirement already satisfied: google-api-python-client<2,>=1.7.11 in /usr/local/lib/python3.10/dist-packages (from tfx-bsl<1.15.0,>=1.14.0->tensorflow-transform) (1.12.11)
# Requirement already satisfied: pandas<2,>=1.0 in /usr/local/lib/python3.10/dist-packages (from tfx-bsl<1.15.0,>=1.14.0->tensorflow-transform) (1.5.3)
# Requirement already satisfied: tensorflow-serving-api<3,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tfx-bsl<1.15.0,>=1.14.0->tensorflow-transform) (2.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<3,>=2.13->tensorflow-transform) (0.42.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl<1.15.0,>=1.14.0->tensorflow-transform) (3.0.1)
# Requirement already satisfied: oauth2client>=1.4.12 in /usr/local/lib/python3.10/dist-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (4.1.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (4.9)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (1.12.1)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.0.2)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4,>=2.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.7.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.13.0)
# Requirement already satisfied: grpcio-status>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (1.48.2)
# Requirement already satisfied: overrides<8.0.0,>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (7.7.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.4.4)
# Requirement already satisfied: deprecated>=1.2.14 in /usr/local/lib/python3.10/dist-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (1.2.14)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.15.4)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage<3,>=2.14.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (1.5.0)
# Requirement already satisfied: docopt in /usr/local/lib/python3.10/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.6.2)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (5.2)
# Requirement already satisfied: pyjsparser>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.17.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo<5.0.0,>=3.8.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (2024.2.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow-transform) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow-transform) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow-transform) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow-transform) (3.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow-transform) (1.3.1)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client>=1.4.12->google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47->tensorflow-transform) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow-transform) (2.1.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow-transform) (3.2.2)

# %% [markdown]
# ## Stage 2: Import project dependencies

# %%
import tempfile
import pandas as pd
import tensorflow as tf
import tensorflow_transform as tft
import tensorflow_transform.beam.impl as tft_beam

from __future__ import print_function
from tensorflow_transform.tf_metadata import dataset_metadata, schema_utils

# %% [markdown]
# ## Stage 3: Dataset preprocessing

# %% [markdown]
# ### Loading the Pollution dataset

# %%
dataset = pd.read_csv("pollution_small.csv")

# %%
dataset.head()

# %% [markdown]
# ### Dropping the Data column

# %%
features = dataset.drop("Date", axis=1)

# %%
features.head()
# Out:
#     pm10    no2    so2   soot
# 0  98.67  14.10  44.38  34.81
# 1  52.33  14.10  29.75  33.06
# 2  74.67  20.50  36.25  39.25
# 3  72.00  17.30  46.44  34.38
# 4  81.00  25.64  56.56  45.59

# %% [markdown]
# ### Converting the dataset from dataframe to list of Python dictionaries

# %%
dict_features = list(features.to_dict("index").values())

# %%
dict_features[:2]
# Out:
# [{'pm10': 98.67, 'no2': 14.1, 'so2': 44.38, 'soot': 34.81},
#  {'pm10': 52.33, 'no2': 14.1, 'so2': 29.75, 'soot': 33.06}]

# %% [markdown]
# ### Defining the dataset metadata

# %%
data_metadata = dataset_metadata.DatasetMetadata(
    schema_utils.schema_from_feature_spec({
        "no2":tf.io.FixedLenFeature([], tf.float32),
        "so2":tf.io.FixedLenFeature([], tf.float32),
        "pm10":tf.io.FixedLenFeature([], tf.float32),
        "soot":tf.io.FixedLenFeature([], tf.float32),
    }
    )
)

# %%
data_metadata
# Out:
# {'_schema': feature {
#   name: "no2"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "pm10"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "so2"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "soot"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# , '_output_record_batches': True}

# %% [markdown]
# ## Stage 4: The preprocessing function

# %%
def preprocessing_fn(inputs):

    no2 = inputs['no2']
    pm10 = inputs['pm10']
    so2 = inputs['so2']
    soot = inputs['soot']

    no2_normalized = no2 - tft.mean(no2)
    so2_normalized = so2 - tft.mean(so2)

    pm10_normalized = tft.scale_to_0_1(pm10)
    soot_normalized = tft.scale_by_min_max(soot)

    return {
        "no2_normalized":no2_normalized,
        "so2_normalized":so2_normalized,
        "pm10_normalized":pm10_normalized,
        "soot_normalized":soot_normalized
    }

# %% [markdown]
# ## Stage 5: Putting everything together
#
# Tensorflow Transform uses **Apache Beam** in the background to perform scalable data transforms. In this function we will use a direct runner.
#
# Arguments to provide to the runner:
#
#     dict_features - This is our dataset converted into Python Dictionary.
#     data_metadata - This is our mada data for the dataset that we have created.
#     preprocessing_fn - The main preprocessing function. Called to perform preprocessing operation per column.
#
#
# This is a special syntax used in Apache Beam. This is used to stack operations and invoke transforms on our data.
#
# ```
# result = data_to_pass | where_to_pass_the_data
# ```
#
# Let's break down our case:
#
# **result**  -> `transformed_dataset, transform_fn`
#
# **data_to_pass** -> `(dict_features, data_metadata)`
#
# **where_to_pass_the_data** -> `tft_beam.AnalyzeAndTransformDataset(preprocessing_fn)`
#
# ```
# transformed_dataset, transform_fn = ((dict_features, data_metadata) | tft_beam.AnalyzeAndTransformDataset(preprocessing_fn))
#
# ```
#
# If you want to learn more about the syntax, we recommend this link:
# https://beam.apache.org/documentation/programming-guide/#applying-transforms
#
# LINKS:
# > more about Apache Beam: https://beam.apache.org/

# %%
def data_transform():

    with tft_beam.Context(temp_dir=tempfile.mkdtemp()):
        transformed_dataset, transform_fn = ((dict_features, data_metadata) | tft_beam.AnalyzeAndTransformDataset(preprocessing_fn))

    transformed_data, transformed_metadata = transformed_dataset

    for i in range(len(transformed_data)):
        print("Raw: ", dict_features[i])
        print("Transformed:", transformed_data[i])

# %%
data_transform()
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# WARNING:absl:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:absl:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:absl:You are outputting instance dicts from `TransformDataset` which will not provide optimal performance. Consider setting  `output_record_batches=True` to upgrade to the TFXIO format (Apache Arrow RecordBatch). Encoding functionality in this module works with both formats.
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-6c6457cb-4d6b-4173-a401-15f3994e7650.json']
# Raw:  {'pm10': 98.67, 'no2': 14.1, 'so2': 44.38, 'soot': 34.81}
# Transformed: {'no2_normalized': -18.57798194885254, 'pm10_normalized': 0.3407169580459595, 'so2_normalized': 28.85540771484375, 'soot_normalized': 0.283423513174057}
# Raw:  {'pm10': 52.33, 'no2': 14.1, 'so2': 29.75, 'soot': 33.06}
# Transformed: {'no2_normalized': -18.57798194885254, 'pm10_normalized': 0.16963857412338257, 'so2_normalized': 14.225406646728516, 'soot_normalized': 0.26620757579803467}
# Raw:  {'pm10': 74.67, 'no2': 20.5, 'so2': 36.25, 'soot': 39.25}
# Transformed: {'no2_normalized': -12.177982330322266, 'pm10_normalized': 0.25211358070373535, 'so2_normalized': 20.725406646728516, 'soot_normalized': 0.32710281014442444}
# Raw:  {'pm10': 72.0, 'no2': 17.3, 'so2': 46.44, 'soot': 34.38}
# Transformed: {'no2_normalized': -15.377983093261719, 'pm10_normalized': 0.24225644767284393, 'so2_normalized': 30.9154052734375, 'soot_normalized': 0.27919331192970276}
# Raw:  {'pm10': 81.0, 'no2': 25.64, 'so2': 56.56, 'soot': 45.59}
# Transformed: {'no2_normalized': -7.037982940673828, 'pm10_normalized': 0.275482714176178, 'so2_normalized': 41.03540802001953, 'soot_normalized': 0.38947367668151855}
# Raw:  {'pm10': 147.0, 'no2': 25.2, 'so2': 42.38, 'soot': 69.33}
# Transformed: {'no2_normalized': -7.4779815673828125, 'pm10_normalized': 0.5191420316696167, 'so2_normalized': 26.85540771484375, 'soot_normalized': 0.6230201721191406}
# Raw:  {'pm10': 185.0, 'no2': 21.91, 'so2': 71.69, 'soot': 84.06}
# Transformed: {'no2_normalized': -10.767982482910156, 'pm10_normalized': 0.659430742263794, 'so2_normalized': 56.165409088134766, 'soot_normalized': 0.7679291367530823}
# Raw:  {'pm10': 148.67, 'no2': 25.09, 'so2': 51.75, 'soot': 74.41}
# Transformed: {'no2_normalized': -7.587982177734375, 'pm10_normalized': 0.5253073573112488, 'so2_normalized': 36.225406646728516, 'soot_normalized': 0.6729956269264221}
# Raw:  {'pm10': 216.0, 'no2': 37.27, 'so2': 63.47, 'soot': 64.06}
# Transformed: {'no2_normalized': 4.592018127441406, 'pm10_normalized': 0.7738767862319946, 'so2_normalized': 47.94540786743164, 'soot_normalized': 0.5711755752563477}
# Raw:  {'pm10': 135.67, 'no2': 23.18, 'so2': 63.13, 'soot': 58.94}
# Transformed: {'no2_normalized': -9.497982025146484, 'pm10_normalized': 0.4773138165473938, 'so2_normalized': 47.60540771484375, 'soot_normalized': 0.5208066701889038}
# Raw:  {'pm10': 138.67, 'no2': 21.64, 'so2': 67.56, 'soot': 49.65}
# Transformed: {'no2_normalized': -11.037982940673828, 'pm10_normalized': 0.488389253616333, 'so2_normalized': 52.035404205322266, 'soot_normalized': 0.42941465973854065}
# Raw:  {'pm10': 96.67, 'no2': 21.0, 'so2': 84.24, 'soot': 49.83}
# Transformed: {'no2_normalized': -11.677982330322266, 'pm10_normalized': 0.3333333432674408, 'so2_normalized': 68.71540832519531, 'soot_normalized': 0.43118545413017273}
# Raw:  {'pm10': 101.0, 'no2': 22.64, 'so2': 83.06, 'soot': 46.44}
# Transformed: {'no2_normalized': -10.037982940673828, 'pm10_normalized': 0.34931889176368713, 'so2_normalized': 67.535400390625, 'soot_normalized': 0.39783570170402527}
# Raw:  {'pm10': 129.33, 'no2': 25.42, 'so2': 78.11, 'soot': 55.53}
# Transformed: {'no2_normalized': -7.25798225402832, 'pm10_normalized': 0.4539078176021576, 'so2_normalized': 62.58540725708008, 'soot_normalized': 0.48726019263267517}
# Raw:  {'pm10': 101.0, 'no2': 21.42, 'so2': 52.44, 'soot': 42.42}
# Transformed: {'no2_normalized': -11.25798225402832, 'pm10_normalized': 0.34931889176368713, 'so2_normalized': 36.9154052734375, 'soot_normalized': 0.3582882285118103}
# Raw:  {'pm10': 83.67, 'no2': 47.08, 'so2': 44.94, 'soot': 39.84}
# Transformed: {'no2_normalized': 14.402019500732422, 'pm10_normalized': 0.2853398323059082, 'so2_normalized': 29.4154052734375, 'soot_normalized': 0.3329070210456848}
# Raw:  {'pm10': 88.67, 'no2': 24.75, 'so2': 41.67, 'soot': 47.79}
# Transformed: {'no2_normalized': -7.927982330322266, 'pm10_normalized': 0.3037988841533661, 'so2_normalized': 26.145404815673828, 'soot_normalized': 0.4111165702342987}
# Raw:  {'pm10': 149.33, 'no2': 34.75, 'so2': 87.22, 'soot': 83.79}
# Transformed: {'no2_normalized': 2.0720176696777344, 'pm10_normalized': 0.527743935585022, 'so2_normalized': 71.69540405273438, 'soot_normalized': 0.7652729749679565}
# Raw:  {'pm10': 41.0, 'no2': 32.08, 'so2': 52.89, 'soot': 46.42}
# Transformed: {'no2_normalized': -0.5979804992675781, 'pm10_normalized': 0.12781038880348206, 'so2_normalized': 37.36540603637695, 'soot_normalized': 0.3976389467716217}
# Raw:  {'pm10': 46.33, 'no2': 26.5, 'so2': 36.5, 'soot': 27.76}
# Transformed: {'no2_normalized': -6.177982330322266, 'pm10_normalized': 0.14748772978782654, 'so2_normalized': 20.975406646728516, 'soot_normalized': 0.21406787633895874}
# Raw:  {'pm10': 26.67, 'no2': 19.67, 'so2': 28.59, 'soot': 16.28}
# Transformed: {'no2_normalized': -13.00798225402832, 'pm10_normalized': 0.07490678876638412, 'so2_normalized': 13.065406799316406, 'soot_normalized': 0.10113133490085602}
# Raw:  {'pm10': 28.33, 'no2': 23.42, 'so2': 19.82, 'soot': 18.17}
# Transformed: {'no2_normalized': -9.25798225402832, 'pm10_normalized': 0.08103518933057785, 'so2_normalized': 4.295406341552734, 'soot_normalized': 0.11972454190254211}
# Raw:  {'pm10': 40.67, 'no2': 25.58, 'so2': 17.94, 'soot': 28.56}
# Transformed: {'no2_normalized': -7.097982406616211, 'pm10_normalized': 0.12659208476543427, 'so2_normalized': 2.415407180786133, 'soot_normalized': 0.22193801403045654}
# Raw:  {'pm10': 38.0, 'no2': 30.33, 'so2': 19.88, 'soot': 27.39}
# Transformed: {'no2_normalized': -2.347982406616211, 'pm10_normalized': 0.11673496663570404, 'so2_normalized': 4.355405807495117, 'soot_normalized': 0.210427924990654}
# Raw:  {'pm10': 25.0, 'no2': 25.33, 'so2': 16.88, 'soot': 16.17}
# Transformed: {'no2_normalized': -7.347982406616211, 'pm10_normalized': 0.06874146312475204, 'so2_normalized': 1.3554058074951172, 'soot_normalized': 0.10004919022321701}
# Raw:  {'pm10': 48.67, 'no2': 32.5, 'so2': 20.35, 'soot': 29.11}
# Transformed: {'no2_normalized': -0.17798233032226562, 'pm10_normalized': 0.15612654387950897, 'so2_normalized': 4.825407028198242, 'soot_normalized': 0.22734874486923218}
# Raw:  {'pm10': 35.67, 'no2': 27.42, 'so2': 25.47, 'soot': 22.28}
# Transformed: {'no2_normalized': -5.25798225402832, 'pm10_normalized': 0.10813304036855698, 'so2_normalized': 9.945405960083008, 'soot_normalized': 0.16015741229057312}
# Raw:  {'pm10': 21.33, 'no2': 18.83, 'so2': 15.83, 'soot': 19.88}
# Transformed: {'no2_normalized': -13.847982406616211, 'pm10_normalized': 0.055192526429891586, 'so2_normalized': 0.3054065704345703, 'soot_normalized': 0.13654696941375732}
# Raw:  {'pm10': 16.67, 'no2': 17.5, 'so2': 14.44, 'soot': 23.71}
# Transformed: {'no2_normalized': -15.177982330322266, 'pm10_normalized': 0.037988703697919846, 'so2_normalized': -1.0845937728881836, 'soot_normalized': 0.17422527074813843}
# Raw:  {'pm10': 29.33, 'no2': 15.42, 'so2': 15.28, 'soot': 27.61}
# Transformed: {'no2_normalized': -17.25798225402832, 'pm10_normalized': 0.08472699671983719, 'so2_normalized': -0.24459362030029297, 'soot_normalized': 0.2125922292470932}
# Raw:  {'pm10': 31.33, 'no2': 17.0, 'so2': 17.39, 'soot': 24.33}
# Transformed: {'no2_normalized': -15.677982330322266, 'pm10_normalized': 0.09211061149835587, 'so2_normalized': 1.8654060363769531, 'soot_normalized': 0.18032464385032654}
# Raw:  {'pm10': 25.67, 'no2': 14.58, 'so2': 20.39, 'soot': 23.0}
# Transformed: {'no2_normalized': -18.09798240661621, 'pm10_normalized': 0.07121498137712479, 'so2_normalized': 4.865406036376953, 'soot_normalized': 0.16724053025245667}
# Raw:  {'pm10': 21.33, 'no2': 14.92, 'so2': 25.11, 'soot': 19.78}
# Transformed: {'no2_normalized': -17.75798225402832, 'pm10_normalized': 0.055192526429891586, 'so2_normalized': 9.585407257080078, 'soot_normalized': 0.1355632096529007}
# Raw:  {'pm10': 19.67, 'no2': 10.42, 'so2': 20.88, 'soot': 19.79}
# Transformed: {'no2_normalized': -22.25798225402832, 'pm10_normalized': 0.04906412586569786, 'so2_normalized': 5.355405807495117, 'soot_normalized': 0.13566158711910248}
# Raw:  {'pm10': 49.67, 'no2': 14.58, 'so2': 19.22, 'soot': 29.84}
# Transformed: {'no2_normalized': -18.09798240661621, 'pm10_normalized': 0.1598183512687683, 'so2_normalized': 3.695405960083008, 'soot_normalized': 0.2345302551984787}
# Raw:  {'pm10': 62.0, 'no2': 30.08, 'so2': 27.06, 'soot': 48.0}
# Transformed: {'no2_normalized': -2.597982406616211, 'pm10_normalized': 0.20533835887908936, 'so2_normalized': 11.535406112670898, 'soot_normalized': 0.41318249702453613}
# Raw:  {'pm10': 30.67, 'no2': 27.67, 'so2': 21.61, 'soot': 35.68}
# Transformed: {'no2_normalized': -5.00798225402832, 'pm10_normalized': 0.08967401832342148, 'so2_normalized': 6.085407257080078, 'soot_normalized': 0.2919822931289673}
# Raw:  {'pm10': 29.33, 'no2': 19.58, 'so2': 16.39, 'soot': 23.11}
# Transformed: {'no2_normalized': -13.097982406616211, 'pm10_normalized': 0.08472699671983719, 'so2_normalized': 0.8654060363769531, 'soot_normalized': 0.16832268238067627}
# Raw:  {'pm10': 27.0, 'no2': 16.17, 'so2': 15.11, 'soot': 23.79}
# Transformed: {'no2_normalized': -16.50798225402832, 'pm10_normalized': 0.07612507790327072, 'so2_normalized': -0.4145936965942383, 'soot_normalized': 0.17501230537891388}
# Raw:  {'pm10': 12.67, 'no2': 14.5, 'so2': 11.5, 'soot': 15.94}
# Transformed: {'no2_normalized': -18.177982330322266, 'pm10_normalized': 0.023221472278237343, 'so2_normalized': -4.024593353271484, 'soot_normalized': 0.09778651595115662}
# Raw:  {'pm10': 30.33, 'no2': 25.0, 'so2': 17.67, 'soot': 30.05}
# Transformed: {'no2_normalized': -7.677982330322266, 'pm10_normalized': 0.08841880410909653, 'so2_normalized': 2.145406723022461, 'soot_normalized': 0.23659615218639374}
# Raw:  {'pm10': 22.0, 'no2': 21.0, 'so2': 15.56, 'soot': 24.05}
# Transformed: {'no2_normalized': -11.677982330322266, 'pm10_normalized': 0.05766604095697403, 'so2_normalized': 0.035407066345214844, 'soot_normalized': 0.17757008969783783}
# Raw:  {'pm10': 18.33, 'no2': 17.82, 'so2': 14.33, 'soot': 17.21}
# Transformed: {'no2_normalized': -14.857982635498047, 'pm10_normalized': 0.04411710426211357, 'so2_normalized': -1.1945934295654297, 'soot_normalized': 0.1102803647518158}
# Raw:  {'pm10': 21.33, 'no2': 17.55, 'so2': 17.35, 'soot': 17.83}
# Transformed: {'no2_normalized': -15.127983093261719, 'pm10_normalized': 0.055192526429891586, 'so2_normalized': 1.8254070281982422, 'soot_normalized': 0.11637973040342331}
# Raw:  {'pm10': 24.0, 'no2': 15.91, 'so2': 13.76, 'soot': 16.94}
# Transformed: {'no2_normalized': -16.767982482910156, 'pm10_normalized': 0.0650496557354927, 'so2_normalized': -1.7645931243896484, 'soot_normalized': 0.10762420296669006}
# Raw:  {'pm10': 18.67, 'no2': 12.91, 'so2': 13.35, 'soot': 14.89}
# Transformed: {'no2_normalized': -19.767982482910156, 'pm10_normalized': 0.04537231847643852, 'so2_normalized': -2.174592971801758, 'soot_normalized': 0.08745696395635605}
# Raw:  {'pm10': 35.33, 'no2': 23.18, 'so2': 16.35, 'soot': 22.06}
# Transformed: {'no2_normalized': -9.497982025146484, 'pm10_normalized': 0.10687784105539322, 'so2_normalized': 0.8254070281982422, 'soot_normalized': 0.1579931080341339}
# Raw:  {'pm10': 37.0, 'no2': 32.27, 'so2': 21.65, 'soot': 33.83}
# Transformed: {'no2_normalized': -0.40798187255859375, 'pm10_normalized': 0.1130431517958641, 'so2_normalized': 6.125406265258789, 'soot_normalized': 0.2737826108932495}
# Raw:  {'pm10': 33.33, 'no2': 19.33, 'so2': 16.28, 'soot': 25.68}
# Transformed: {'no2_normalized': -13.347982406616211, 'pm10_normalized': 0.09949422627687454, 'so2_normalized': 0.7554073333740234, 'soot_normalized': 0.19360551238059998}
# Raw:  {'pm10': 20.0, 'no2': 13.67, 'so2': 18.56, 'soot': 19.53}
# Transformed: {'no2_normalized': -19.00798225402832, 'pm10_normalized': 0.050282422453165054, 'so2_normalized': 3.0354061126708984, 'soot_normalized': 0.13310378789901733}
# Raw:  {'pm10': 34.33, 'no2': 19.92, 'so2': 15.33, 'soot': 21.89}
# Transformed: {'no2_normalized': -12.75798225402832, 'pm10_normalized': 0.10318603366613388, 'so2_normalized': -0.1945934295654297, 'soot_normalized': 0.1563207060098648}
# Raw:  {'pm10': 52.67, 'no2': 23.0, 'so2': 17.33, 'soot': 29.32}
# Transformed: {'no2_normalized': -9.677982330322266, 'pm10_normalized': 0.17089377343654633, 'so2_normalized': 1.8054065704345703, 'soot_normalized': 0.2294146567583084}
# Raw:  {'pm10': 75.33, 'no2': 23.17, 'so2': 13.78, 'soot': 35.26}
# Transformed: {'no2_normalized': -9.50798225402832, 'pm10_normalized': 0.25455018877983093, 'so2_normalized': -1.744593620300293, 'soot_normalized': 0.28785043954849243}
# Raw:  {'pm10': 114.33, 'no2': 39.58, 'so2': 31.72, 'soot': 53.37}
# Transformed: {'no2_normalized': 6.902019500732422, 'pm10_normalized': 0.3985306918621063, 'so2_normalized': 16.195405960083008, 'soot_normalized': 0.46601080894470215}
# Raw:  {'pm10': 123.0, 'no2': 39.08, 'so2': 35.06, 'soot': 52.26}
# Transformed: {'no2_normalized': 6.402019500732422, 'pm10_normalized': 0.4305386543273926, 'so2_normalized': 19.53540802001953, 'soot_normalized': 0.4550909698009491}
# Raw:  {'pm10': 89.0, 'no2': 29.92, 'so2': 23.06, 'soot': 39.63}
# Transformed: {'no2_normalized': -2.7579822540283203, 'pm10_normalized': 0.3050171732902527, 'so2_normalized': 7.535406112670898, 'soot_normalized': 0.3308411240577698}
# Raw:  {'pm10': 72.33, 'no2': 31.0, 'so2': 23.72, 'soot': 37.89}
# Transformed: {'no2_normalized': -1.6779823303222656, 'pm10_normalized': 0.24347475171089172, 'so2_normalized': 8.195405960083008, 'soot_normalized': 0.3137235641479492}
# Raw:  {'pm10': 44.33, 'no2': 29.58, 'so2': 23.94, 'soot': 35.47}
# Transformed: {'no2_normalized': -3.097982406616211, 'pm10_normalized': 0.14010411500930786, 'so2_normalized': 8.415407180786133, 'soot_normalized': 0.28991639614105225}
# Raw:  {'pm10': 36.67, 'no2': 31.5, 'so2': 20.72, 'soot': 35.47}
# Transformed: {'no2_normalized': -1.1779823303222656, 'pm10_normalized': 0.11182485520839691, 'so2_normalized': 5.195405960083008, 'soot_normalized': 0.28991639614105225}
# Raw:  {'pm10': 75.5, 'no2': 35.13, 'so2': 28.65, 'soot': 48.47}
# Transformed: {'no2_normalized': 2.4520187377929688, 'pm10_normalized': 0.255177766084671, 'so2_normalized': 13.125406265258789, 'soot_normalized': 0.4178062081336975}
# Raw:  {'pm10': 56.75, 'no2': 30.25, 'so2': 26.5, 'soot': 41.53}
# Transformed: {'no2_normalized': -2.4279823303222656, 'pm10_normalized': 0.18595635890960693, 'so2_normalized': 10.975406646728516, 'soot_normalized': 0.34953269362449646}
# Raw:  {'pm10': 56.5, 'no2': 27.94, 'so2': 27.9, 'soot': 43.32}
# Transformed: {'no2_normalized': -4.737981796264648, 'pm10_normalized': 0.1850334107875824, 'so2_normalized': 12.375406265258789, 'soot_normalized': 0.3671421408653259}
# Raw:  {'pm10': 38.5, 'no2': 16.75, 'so2': 19.0, 'soot': 26.11}
# Transformed: {'no2_normalized': -15.927982330322266, 'pm10_normalized': 0.11858087033033371, 'so2_normalized': 3.4754066467285156, 'soot_normalized': 0.19783571362495422}
# Raw:  {'pm10': 22.75, 'no2': 10.56, 'so2': 15.75, 'soot': 21.11}
# Transformed: {'no2_normalized': -22.11798095703125, 'pm10_normalized': 0.060434892773628235, 'so2_normalized': 0.22540664672851562, 'soot_normalized': 0.14864732325077057}
# Raw:  {'pm10': 33.0, 'no2': 17.81, 'so2': 15.8, 'soot': 23.79}
# Transformed: {'no2_normalized': -14.867982864379883, 'pm10_normalized': 0.09827592223882675, 'so2_normalized': 0.2754068374633789, 'soot_normalized': 0.17501230537891388}
# Raw:  {'pm10': 29.83, 'no2': 15.81, 'so2': 11.35, 'soot': 18.21}
# Transformed: {'no2_normalized': -16.86798095703125, 'pm10_normalized': 0.08657290041446686, 'so2_normalized': -4.174592971801758, 'soot_normalized': 0.12011804431676865}
# Raw:  {'pm10': 31.17, 'no2': 17.44, 'so2': 11.9, 'soot': 22.32}
# Transformed: {'no2_normalized': -15.237981796264648, 'pm10_normalized': 0.09151992201805115, 'so2_normalized': -3.624593734741211, 'soot_normalized': 0.16055090725421906}
# Raw:  {'pm10': 33.17, 'no2': 22.81, 'so2': 17.1, 'soot': 26.16}
# Transformed: {'no2_normalized': -9.867982864379883, 'pm10_normalized': 0.09890352189540863, 'so2_normalized': 1.5754070281982422, 'soot_normalized': 0.19832758605480194}
# Raw:  {'pm10': 42.0, 'no2': 20.75, 'so2': 14.5, 'soot': 25.11}
# Transformed: {'no2_normalized': -11.927982330322266, 'pm10_normalized': 0.1315021961927414, 'so2_normalized': -1.0245933532714844, 'soot_normalized': 0.18799804151058197}
# Raw:  {'pm10': 32.67, 'no2': 22.13, 'so2': 17.85, 'soot': 24.83}
# Transformed: {'no2_normalized': -10.547983169555664, 'pm10_normalized': 0.09705761820077896, 'so2_normalized': 2.325407028198242, 'soot_normalized': 0.18524347245693207}
# Raw:  {'pm10': 25.2, 'no2': 17.44, 'so2': 14.25, 'soot': 22.0}
# Transformed: {'no2_normalized': -15.237981796264648, 'pm10_normalized': 0.06947982311248779, 'so2_normalized': -1.2745933532714844, 'soot_normalized': 0.15740284323692322}
# Raw:  {'pm10': 25.67, 'no2': 18.13, 'so2': 16.2, 'soot': 20.22}
# Transformed: {'no2_normalized': -14.547983169555664, 'pm10_normalized': 0.07121498137712479, 'so2_normalized': 0.6754074096679688, 'soot_normalized': 0.13989177346229553}
# Raw:  {'pm10': 42.0, 'no2': 18.06, 'so2': 14.0, 'soot': 21.83}
# Transformed: {'no2_normalized': -14.617982864379883, 'pm10_normalized': 0.1315021961927414, 'so2_normalized': -1.5245933532714844, 'soot_normalized': 0.1557304412126541}
# Raw:  {'pm10': 72.0, 'no2': 25.44, 'so2': 25.25, 'soot': 35.72}
# Transformed: {'no2_normalized': -7.237981796264648, 'pm10_normalized': 0.24225644767284393, 'so2_normalized': 9.725406646728516, 'soot_normalized': 0.2923758029937744}
# Raw:  {'pm10': 38.83, 'no2': 18.69, 'so2': 16.55, 'soot': 20.33}
# Transformed: {'no2_normalized': -13.987981796264648, 'pm10_normalized': 0.1197991669178009, 'so2_normalized': 1.0254058837890625, 'soot_normalized': 0.14097392559051514}
# Raw:  {'pm10': 41.33, 'no2': 17.19, 'so2': 13.65, 'soot': 18.78}
# Transformed: {'no2_normalized': -15.487981796264648, 'pm10_normalized': 0.12902869284152985, 'so2_normalized': -1.874593734741211, 'soot_normalized': 0.12572553753852844}
# Raw:  {'pm10': 23.17, 'no2': 12.38, 'so2': 11.7, 'soot': 16.06}
# Transformed: {'no2_normalized': -20.29798126220703, 'pm10_normalized': 0.06198545917868614, 'so2_normalized': -3.8245935440063477, 'soot_normalized': 0.0989670380949974}
# Raw:  {'pm10': 27.0, 'no2': 16.63, 'so2': 12.3, 'soot': 18.28}
# Transformed: {'no2_normalized': -16.047983169555664, 'pm10_normalized': 0.07612507790327072, 'so2_normalized': -3.224593162536621, 'soot_normalized': 0.12080669403076172}
# Raw:  {'pm10': 38.33, 'no2': 18.75, 'so2': 15.0, 'soot': 19.05}
# Transformed: {'no2_normalized': -13.927982330322266, 'pm10_normalized': 0.11795326322317123, 'so2_normalized': -0.5245933532714844, 'soot_normalized': 0.12838169932365417}
# Raw:  {'pm10': 26.6, 'no2': 15.75, 'so2': 13.55, 'soot': 15.74}
# Transformed: {'no2_normalized': -16.927982330322266, 'pm10_normalized': 0.07464835792779922, 'so2_normalized': -1.974593162536621, 'soot_normalized': 0.09581898152828217}
# Raw:  {'pm10': 31.0, 'no2': 14.94, 'so2': 12.4, 'soot': 16.42}
# Transformed: {'no2_normalized': -17.73798370361328, 'pm10_normalized': 0.09089230746030807, 'so2_normalized': -3.124593734741211, 'soot_normalized': 0.10250860452651978}
# Raw:  {'pm10': 28.0, 'no2': 20.0, 'so2': 14.15, 'soot': 17.79}
# Transformed: {'no2_normalized': -12.677982330322266, 'pm10_normalized': 0.07981688529253006, 'so2_normalized': -1.374593734741211, 'soot_normalized': 0.11598623543977737}
# Raw:  {'pm10': 21.83, 'no2': 21.27, 'so2': 13.5, 'soot': 14.59}
# Transformed: {'no2_normalized': -11.407981872558594, 'pm10_normalized': 0.057038433849811554, 'so2_normalized': -2.0245933532714844, 'soot_normalized': 0.08450565487146378}
# Raw:  {'pm10': 28.83, 'no2': 18.57, 'so2': 12.6, 'soot': 17.0}
# Transformed: {'no2_normalized': -14.107982635498047, 'pm10_normalized': 0.08288109302520752, 'so2_normalized': -2.924592971801758, 'soot_normalized': 0.10821446031332016}
# Raw:  {'pm10': 34.67, 'no2': 26.33, 'so2': 17.4, 'soot': 21.24}
# Transformed: {'no2_normalized': -6.347982406616211, 'pm10_normalized': 0.10444123297929764, 'so2_normalized': 1.875406265258789, 'soot_normalized': 0.14992621541023254}
# Raw:  {'pm10': 34.17, 'no2': 28.0, 'so2': 17.95, 'soot': 20.88}
# Transformed: {'no2_normalized': -4.677982330322266, 'pm10_normalized': 0.10259532928466797, 'so2_normalized': 2.4254074096679688, 'soot_normalized': 0.14638464152812958}
# Raw:  {'pm10': 27.33, 'no2': 22.6, 'so2': 14.85, 'soot': 16.71}
# Transformed: {'no2_normalized': -10.077981948852539, 'pm10_normalized': 0.07734338194131851, 'so2_normalized': -0.6745929718017578, 'soot_normalized': 0.10536152124404907}
# Raw:  {'pm10': 47.83, 'no2': 13.29, 'so2': 10.95, 'soot': 15.88}
# Transformed: {'no2_normalized': -19.387981414794922, 'pm10_normalized': 0.15302544832229614, 'so2_normalized': -4.574593544006348, 'soot_normalized': 0.09719625860452652}
# Raw:  {'pm10': 29.83, 'no2': 19.57, 'so2': 12.05, 'soot': 16.82}
# Transformed: {'no2_normalized': -13.107982635498047, 'pm10_normalized': 0.08657290041446686, 'so2_normalized': -3.474593162536621, 'soot_normalized': 0.10644367337226868}
# Raw:  {'pm10': 34.2, 'no2': 19.21, 'so2': 9.9, 'soot': 19.44}
# Transformed: {'no2_normalized': -13.46798324584961, 'pm10_normalized': 0.10270609706640244, 'so2_normalized': -5.624593734741211, 'soot_normalized': 0.1322184056043625}
# Raw:  {'pm10': 60.83, 'no2': 19.47, 'so2': 12.55, 'soot': 24.65}
# Transformed: {'no2_normalized': -13.207983016967773, 'pm10_normalized': 0.20101894438266754, 'so2_normalized': -2.974593162536621, 'soot_normalized': 0.18347269296646118}
# Raw:  {'pm10': 39.17, 'no2': 17.46, 'so2': 10.95, 'soot': 20.5}
# Transformed: {'no2_normalized': -15.21798324584961, 'pm10_normalized': 0.12105437368154526, 'so2_normalized': -4.574593544006348, 'soot_normalized': 0.14264632761478424}
# Raw:  {'pm10': 27.5, 'no2': 16.07, 'so2': 10.3, 'soot': 16.27}
# Transformed: {'no2_normalized': -16.607982635498047, 'pm10_normalized': 0.07797098159790039, 'so2_normalized': -5.224593162536621, 'soot_normalized': 0.10103295743465424}
# Raw:  {'pm10': 35.33, 'no2': 20.93, 'so2': 11.7, 'soot': 21.27}
# Transformed: {'no2_normalized': -11.747982025146484, 'pm10_normalized': 0.10687784105539322, 'so2_normalized': -3.8245935440063477, 'soot_normalized': 0.1502213478088379}
# Raw:  {'pm10': 51.83, 'no2': 31.07, 'so2': 12.45, 'soot': 29.2}
# Transformed: {'no2_normalized': -1.6079826354980469, 'pm10_normalized': 0.1677926778793335, 'so2_normalized': -3.0745935440063477, 'soot_normalized': 0.22823414206504822}
# Raw:  {'pm10': 53.6, 'no2': 29.0, 'so2': 14.1, 'soot': 27.6}
# Transformed: {'no2_normalized': -3.6779823303222656, 'pm10_normalized': 0.17432716488838196, 'so2_normalized': -1.4245929718017578, 'soot_normalized': 0.21249385178089142}
# Raw:  {'pm10': 48.0, 'no2': 30.36, 'so2': 12.9, 'soot': 27.63}
# Transformed: {'no2_normalized': -2.317981719970703, 'pm10_normalized': 0.15365304052829742, 'so2_normalized': -2.624593734741211, 'soot_normalized': 0.21278896927833557}
# Raw:  {'pm10': 39.0, 'no2': 30.8, 'so2': 11.25, 'soot': 32.88}
# Transformed: {'no2_normalized': -1.8779830932617188, 'pm10_normalized': 0.12042677402496338, 'so2_normalized': -4.274593353271484, 'soot_normalized': 0.264436811208725}
# Raw:  {'pm10': 65.8, 'no2': 34.33, 'so2': 14.15, 'soot': 42.71}
# Transformed: {'no2_normalized': 1.6520195007324219, 'pm10_normalized': 0.21936723589897156, 'so2_normalized': -1.374593734741211, 'soot_normalized': 0.3611411452293396}
# Raw:  {'pm10': 61.4, 'no2': 38.6, 'so2': 19.2, 'soot': 42.67}
# Transformed: {'no2_normalized': 5.922016143798828, 'pm10_normalized': 0.2031232714653015, 'so2_normalized': 3.6754074096679688, 'soot_normalized': 0.36074763536453247}
# Raw:  {'pm10': 39.17, 'no2': 18.0, 'so2': 10.3, 'soot': 18.61}
# Transformed: {'no2_normalized': -14.677982330322266, 'pm10_normalized': 0.12105437368154526, 'so2_normalized': -5.224593162536621, 'soot_normalized': 0.12405312806367874}
# Raw:  {'pm10': 35.33, 'no2': 15.27, 'so2': 9.8, 'soot': 12.89}
# Transformed: {'no2_normalized': -17.407981872558594, 'pm10_normalized': 0.10687784105539322, 'so2_normalized': -5.724593162536621, 'soot_normalized': 0.06778160482645035}
# Raw:  {'pm10': 44.0, 'no2': 15.36, 'so2': 8.8, 'soot': 13.94}
# Transformed: {'no2_normalized': -17.317981719970703, 'pm10_normalized': 0.13888581097126007, 'so2_normalized': -6.724593162536621, 'soot_normalized': 0.07811115682125092}
# Raw:  {'pm10': 32.83, 'no2': 22.57, 'so2': 11.6, 'soot': 24.76}
# Transformed: {'no2_normalized': -10.107982635498047, 'pm10_normalized': 0.09764832258224487, 'so2_normalized': -3.924592971801758, 'soot_normalized': 0.1845548450946808}
# Raw:  {'pm10': 40.83, 'no2': 25.5, 'so2': 12.3, 'soot': 29.24}
# Transformed: {'no2_normalized': -7.177982330322266, 'pm10_normalized': 0.12718278169631958, 'so2_normalized': -3.224593162536621, 'soot_normalized': 0.22862763702869415}
# Raw:  {'pm10': 45.67, 'no2': 39.69, 'so2': 14.7, 'soot': 42.74}
# Transformed: {'no2_normalized': 7.012016296386719, 'pm10_normalized': 0.14505112171173096, 'so2_normalized': -0.8245935440063477, 'soot_normalized': 0.36143630743026733}
# Raw:  {'pm10': 27.67, 'no2': 24.13, 'so2': 10.5, 'soot': 17.84}
# Transformed: {'no2_normalized': -8.547983169555664, 'pm10_normalized': 0.07859859615564346, 'so2_normalized': -5.024593353271484, 'soot_normalized': 0.11647810786962509}
# Raw:  {'pm10': 24.67, 'no2': 22.94, 'so2': 9.45, 'soot': 17.11}
# Transformed: {'no2_normalized': -9.737981796264648, 'pm10_normalized': 0.06752317398786545, 'so2_normalized': -6.074593544006348, 'soot_normalized': 0.10929661244153976}
# Raw:  {'pm10': 34.0, 'no2': 23.31, 'so2': 9.55, 'soot': 23.05}
# Transformed: {'no2_normalized': -9.367982864379883, 'pm10_normalized': 0.10196772962808609, 'so2_normalized': -5.974593162536621, 'soot_normalized': 0.16773240268230438}
# Raw:  {'pm10': 28.17, 'no2': 23.75, 'so2': 9.2, 'soot': 19.68}
# Transformed: {'no2_normalized': -8.927982330322266, 'pm10_normalized': 0.08044449985027313, 'so2_normalized': -6.324593544006348, 'soot_normalized': 0.13457943499088287}
# Raw:  {'pm10': 34.33, 'no2': 22.94, 'so2': 9.1, 'soot': 19.05}
# Transformed: {'no2_normalized': -9.737981796264648, 'pm10_normalized': 0.10318603366613388, 'so2_normalized': -6.424592971801758, 'soot_normalized': 0.12838169932365417}
# Raw:  {'pm10': 29.67, 'no2': 20.5, 'so2': 8.75, 'soot': 18.89}
# Transformed: {'no2_normalized': -12.177982330322266, 'pm10_normalized': 0.08598221093416214, 'so2_normalized': -6.774593353271484, 'soot_normalized': 0.12680765986442566}
# Raw:  {'pm10': 19.75, 'no2': 20.5, 'so2': 8.45, 'soot': 17.05}
# Transformed: {'no2_normalized': -12.177982330322266, 'pm10_normalized': 0.04935947060585022, 'so2_normalized': -7.074593544006348, 'soot_normalized': 0.10870633274316788}
# Raw:  {'pm10': 28.83, 'no2': 28.81, 'so2': 9.5, 'soot': 28.32}
# Transformed: {'no2_normalized': -3.867982864379883, 'pm10_normalized': 0.08288109302520752, 'so2_normalized': -6.024593353271484, 'soot_normalized': 0.21957696974277496}
# Raw:  {'pm10': 39.0, 'no2': 28.13, 'so2': 11.3, 'soot': 27.16}
# Transformed: {'no2_normalized': -4.547983169555664, 'pm10_normalized': 0.12042677402496338, 'so2_normalized': -4.224593162536621, 'soot_normalized': 0.2081652730703354}
# Raw:  {'pm10': 24.5, 'no2': 18.38, 'so2': 8.85, 'soot': 13.47}
# Transformed: {'no2_normalized': -14.297983169555664, 'pm10_normalized': 0.06689555943012238, 'so2_normalized': -6.674592971801758, 'soot_normalized': 0.07348746061325073}
# Raw:  {'pm10': 23.33, 'no2': 17.75, 'so2': 7.55, 'soot': 14.42}
# Transformed: {'no2_normalized': -14.927982330322266, 'pm10_normalized': 0.06257614493370056, 'so2_normalized': -7.974593162536621, 'soot_normalized': 0.08283325284719467}
# Raw:  {'pm10': 24.2, 'no2': 19.38, 'so2': 9.55, 'soot': 16.95}
# Transformed: {'no2_normalized': -13.297983169555664, 'pm10_normalized': 0.06578801572322845, 'so2_normalized': -5.974593162536621, 'soot_normalized': 0.10772258043289185}
# Raw:  {'pm10': 24.2, 'no2': 23.93, 'so2': 9.05, 'soot': 22.95}
# Transformed: {'no2_normalized': -8.747982025146484, 'pm10_normalized': 0.06578801572322845, 'so2_normalized': -6.474593162536621, 'soot_normalized': 0.16674865782260895}
# Raw:  {'pm10': 17.6, 'no2': 21.2, 'so2': 8.85, 'soot': 19.26}
# Transformed: {'no2_normalized': -11.477981567382812, 'pm10_normalized': 0.04142208769917488, 'so2_normalized': -6.674592971801758, 'soot_normalized': 0.1304476112127304}
# Raw:  {'pm10': 28.0, 'no2': 15.5, 'so2': 7.9, 'soot': 18.63}
# Transformed: {'no2_normalized': -17.177982330322266, 'pm10_normalized': 0.07981688529253006, 'so2_normalized': -7.624593257904053, 'soot_normalized': 0.12424986809492111}
# Raw:  {'pm10': 25.67, 'no2': 11.69, 'so2': 7.85, 'soot': 16.68}
# Transformed: {'no2_normalized': -20.98798370361328, 'pm10_normalized': 0.07121498137712479, 'so2_normalized': -7.674593448638916, 'soot_normalized': 0.10506640374660492}
# Raw:  {'pm10': 37.0, 'no2': 19.94, 'so2': 9.3, 'soot': 21.74}
# Transformed: {'no2_normalized': -12.737981796264648, 'pm10_normalized': 0.1130431517958641, 'so2_normalized': -6.224593162536621, 'soot_normalized': 0.15484505891799927}
# Raw:  {'pm10': 33.67, 'no2': 22.75, 'so2': 10.1, 'soot': 24.89}
# Transformed: {'no2_normalized': -9.927982330322266, 'pm10_normalized': 0.1007494255900383, 'so2_normalized': -5.424592971801758, 'soot_normalized': 0.18583373725414276}
# Raw:  {'pm10': 25.17, 'no2': 18.44, 'so2': 8.6, 'soot': 20.05}
# Transformed: {'no2_normalized': -14.237981796264648, 'pm10_normalized': 0.06936907768249512, 'so2_normalized': -6.924592971801758, 'soot_normalized': 0.13821937143802643}
# Raw:  {'pm10': 22.0, 'no2': 21.0, 'so2': 8.8, 'soot': 21.05}
# Transformed: {'no2_normalized': -11.677982330322266, 'pm10_normalized': 0.05766604095697403, 'so2_normalized': -6.724593162536621, 'soot_normalized': 0.14805704355239868}
# Raw:  {'pm10': 23.0, 'no2': 21.75, 'so2': 8.5, 'soot': 21.74}
# Transformed: {'no2_normalized': -10.927982330322266, 'pm10_normalized': 0.06135784462094307, 'so2_normalized': -7.024593353271484, 'soot_normalized': 0.15484505891799927}
# Raw:  {'pm10': 26.67, 'no2': 29.63, 'so2': 10.85, 'soot': 30.63}
# Transformed: {'no2_normalized': -3.047983169555664, 'pm10_normalized': 0.07490678876638412, 'so2_normalized': -4.674592971801758, 'soot_normalized': 0.24230200052261353}
# Raw:  {'pm10': 35.75, 'no2': 33.25, 'so2': 13.4, 'soot': 37.0}
# Transformed: {'no2_normalized': 0.5720176696777344, 'pm10_normalized': 0.10842839628458023, 'so2_normalized': -2.124593734741211, 'soot_normalized': 0.3049680292606354}
# Raw:  {'pm10': 31.0, 'no2': 30.13, 'so2': 11.55, 'soot': 30.42}
# Transformed: {'no2_normalized': -2.547983169555664, 'pm10_normalized': 0.09089230746030807, 'so2_normalized': -3.974593162536621, 'soot_normalized': 0.2402361035346985}
# Raw:  {'pm10': 36.5, 'no2': 30.31, 'so2': 17.4, 'soot': 27.63}
# Transformed: {'no2_normalized': -2.367982864379883, 'pm10_normalized': 0.11119724810123444, 'so2_normalized': 1.875406265258789, 'soot_normalized': 0.21278896927833557}
# Raw:  {'pm10': 31.5, 'no2': 26.13, 'so2': 10.65, 'soot': 22.37}
# Transformed: {'no2_normalized': -6.547983169555664, 'pm10_normalized': 0.09273821115493774, 'so2_normalized': -4.874593734741211, 'soot_normalized': 0.16104279458522797}
# Raw:  {'pm10': 20.17, 'no2': 17.25, 'so2': 9.1, 'soot': 18.21}
# Transformed: {'no2_normalized': -15.427982330322266, 'pm10_normalized': 0.05091002956032753, 'so2_normalized': -6.424592971801758, 'soot_normalized': 0.12011804431676865}
# Raw:  {'pm10': 32.5, 'no2': 22.44, 'so2': 9.35, 'soot': 22.95}
# Transformed: {'no2_normalized': -10.237981796264648, 'pm10_normalized': 0.09643001854419708, 'so2_normalized': -6.174592971801758, 'soot_normalized': 0.16674865782260895}
# Raw:  {'pm10': 47.67, 'no2': 29.81, 'so2': 12.95, 'soot': 28.84}
# Transformed: {'no2_normalized': -2.867982864379883, 'pm10_normalized': 0.15243473649024963, 'so2_normalized': -2.5745935440063477, 'soot_normalized': 0.22469256818294525}
# Raw:  {'pm10': 40.17, 'no2': 28.81, 'so2': 13.3, 'soot': 25.42}
# Transformed: {'no2_normalized': -3.867982864379883, 'pm10_normalized': 0.1247461810708046, 'so2_normalized': -2.224593162536621, 'soot_normalized': 0.19104771316051483}
# Raw:  {'pm10': 44.17, 'no2': 27.06, 'so2': 11.9, 'soot': 25.37}
# Transformed: {'no2_normalized': -5.617982864379883, 'pm10_normalized': 0.13951341807842255, 'so2_normalized': -3.624593734741211, 'soot_normalized': 0.19055584073066711}
# Raw:  {'pm10': 38.17, 'no2': 25.19, 'so2': 11.8, 'soot': 23.32}
# Transformed: {'no2_normalized': -7.487981796264648, 'pm10_normalized': 0.11736256629228592, 'so2_normalized': -3.724593162536621, 'soot_normalized': 0.1703885793685913}
# Raw:  {'pm10': 34.17, 'no2': 19.07, 'so2': 10.25, 'soot': 21.11}
# Transformed: {'no2_normalized': -13.607982635498047, 'pm10_normalized': 0.10259532928466797, 'so2_normalized': -5.274593353271484, 'soot_normalized': 0.14864732325077057}
# Raw:  {'pm10': 31.17, 'no2': 16.4, 'so2': 9.45, 'soot': 16.94}
# Transformed: {'no2_normalized': -16.277982711791992, 'pm10_normalized': 0.09151992201805115, 'so2_normalized': -6.074593544006348, 'soot_normalized': 0.10762420296669006}
# Raw:  {'pm10': 35.67, 'no2': 25.67, 'so2': 10.0, 'soot': 20.78}
# Transformed: {'no2_normalized': -7.00798225402832, 'pm10_normalized': 0.10813304036855698, 'so2_normalized': -5.524593353271484, 'soot_normalized': 0.14540089666843414}
# Raw:  {'pm10': 43.17, 'no2': 34.6, 'so2': 13.5, 'soot': 27.78}
# Transformed: {'no2_normalized': 1.9220161437988281, 'pm10_normalized': 0.1358216106891632, 'so2_normalized': -2.0245933532714844, 'soot_normalized': 0.2142646312713623}
# Raw:  {'pm10': 23.67, 'no2': 23.27, 'so2': 9.75, 'soot': 16.89}
# Transformed: {'no2_normalized': -9.407981872558594, 'pm10_normalized': 0.06383135914802551, 'so2_normalized': -5.774593353271484, 'soot_normalized': 0.10713230818510056}
# Raw:  {'pm10': 29.5, 'no2': 25.0, 'so2': 10.45, 'soot': 23.72}
# Transformed: {'no2_normalized': -7.677982330322266, 'pm10_normalized': 0.08535459637641907, 'so2_normalized': -5.074593544006348, 'soot_normalized': 0.1743236482143402}
# Raw:  {'pm10': 39.17, 'no2': 30.6, 'so2': 10.4, 'soot': 25.89}
# Transformed: {'no2_normalized': -2.077981948852539, 'pm10_normalized': 0.12105437368154526, 'so2_normalized': -5.124593734741211, 'soot_normalized': 0.19567140936851501}
# Raw:  {'pm10': 35.0, 'no2': 29.07, 'so2': 11.55, 'soot': 22.16}
# Transformed: {'no2_normalized': -3.607982635498047, 'pm10_normalized': 0.10565953701734543, 'so2_normalized': -3.974593162536621, 'soot_normalized': 0.15897688269615173}
# Raw:  {'pm10': 28.0, 'no2': 20.33, 'so2': 9.55, 'soot': 17.42}
# Transformed: {'no2_normalized': -12.347982406616211, 'pm10_normalized': 0.07981688529253006, 'so2_normalized': -5.974593162536621, 'soot_normalized': 0.11234628409147263}
# Raw:  {'pm10': 20.5, 'no2': 18.0, 'so2': 8.9, 'soot': 16.33}
# Transformed: {'no2_normalized': -14.677982330322266, 'pm10_normalized': 0.052128326147794724, 'so2_normalized': -6.624593734741211, 'soot_normalized': 0.10162321478128433}
# Raw:  {'pm10': 21.17, 'no2': 19.47, 'so2': 9.45, 'soot': 17.11}
# Transformed: {'no2_normalized': -13.207983016967773, 'pm10_normalized': 0.05460184067487717, 'so2_normalized': -6.074593544006348, 'soot_normalized': 0.10929661244153976}
# Raw:  {'pm10': 23.33, 'no2': 17.67, 'so2': 9.7, 'soot': 17.61}
# Transformed: {'no2_normalized': -15.00798225402832, 'pm10_normalized': 0.06257614493370056, 'so2_normalized': -5.824593544006348, 'soot_normalized': 0.11421544849872589}
# Raw:  {'pm10': 28.33, 'no2': 19.73, 'so2': 10.5, 'soot': 17.67}
# Transformed: {'no2_normalized': -12.947982788085938, 'pm10_normalized': 0.08103518933057785, 'so2_normalized': -5.024593353271484, 'soot_normalized': 0.11480570584535599}
# Raw:  {'pm10': 28.5, 'no2': 22.33, 'so2': 9.1, 'soot': 16.42}
# Transformed: {'no2_normalized': -10.347982406616211, 'pm10_normalized': 0.08166278898715973, 'so2_normalized': -6.424592971801758, 'soot_normalized': 0.10250860452651978}
# Raw:  {'pm10': 21.67, 'no2': 23.25, 'so2': 9.15, 'soot': 15.79}
# Transformed: {'no2_normalized': -9.427982330322266, 'pm10_normalized': 0.056447744369506836, 'so2_normalized': -6.374593734741211, 'soot_normalized': 0.09631086885929108}
# Raw:  {'pm10': 26.17, 'no2': 23.87, 'so2': 9.7, 'soot': 17.21}
# Transformed: {'no2_normalized': -8.807981491088867, 'pm10_normalized': 0.07306088507175446, 'so2_normalized': -5.824593544006348, 'soot_normalized': 0.1102803647518158}
# Raw:  {'pm10': 25.67, 'no2': 24.56, 'so2': 10.0, 'soot': 20.21}
# Transformed: {'no2_normalized': -8.117982864379883, 'pm10_normalized': 0.07121498137712479, 'so2_normalized': -5.524593353271484, 'soot_normalized': 0.13979339599609375}
# Raw:  {'pm10': 23.67, 'no2': 26.5, 'so2': 9.35, 'soot': 17.26}
# Transformed: {'no2_normalized': -6.177982330322266, 'pm10_normalized': 0.06383135914802551, 'so2_normalized': -6.174592971801758, 'soot_normalized': 0.1107722595334053}
# Raw:  {'pm10': 24.17, 'no2': 25.0, 'so2': 9.3, 'soot': 20.42}
# Transformed: {'no2_normalized': -7.677982330322266, 'pm10_normalized': 0.06567727029323578, 'so2_normalized': -6.224593162536621, 'soot_normalized': 0.14185932278633118}
# Raw:  {'pm10': 27.5, 'no2': 24.5, 'so2': 9.75, 'soot': 14.89}
# Transformed: {'no2_normalized': -8.177982330322266, 'pm10_normalized': 0.07797098159790039, 'so2_normalized': -5.774593353271484, 'soot_normalized': 0.08745696395635605}
# Raw:  {'pm10': 25.83, 'no2': 25.27, 'so2': 9.85, 'soot': 23.95}
# Transformed: {'no2_normalized': -7.407981872558594, 'pm10_normalized': 0.0718056708574295, 'so2_normalized': -5.674592971801758, 'soot_normalized': 0.1765863299369812}
# Raw:  {'pm10': 38.5, 'no2': 29.94, 'so2': 11.9, 'soot': 25.16}
# Transformed: {'no2_normalized': -2.7379817962646484, 'pm10_normalized': 0.11858087033033371, 'so2_normalized': -3.624593734741211, 'soot_normalized': 0.1884899139404297}
# Raw:  {'pm10': 31.83, 'no2': 26.38, 'so2': 10.85, 'soot': 20.79}
# Transformed: {'no2_normalized': -6.297983169555664, 'pm10_normalized': 0.09395651519298553, 'so2_normalized': -4.674592971801758, 'soot_normalized': 0.14549927413463593}
# Raw:  {'pm10': 30.8, 'no2': 20.69, 'so2': 9.6, 'soot': 16.11}
# Transformed: {'no2_normalized': -11.987981796264648, 'pm10_normalized': 0.09015394002199173, 'so2_normalized': -5.924592971801758, 'soot_normalized': 0.09945893287658691}
# Raw:  {'pm10': 18.5, 'no2': 21.69, 'so2': 9.95, 'soot': 17.79}
# Transformed: {'no2_normalized': -10.987981796264648, 'pm10_normalized': 0.04474471136927605, 'so2_normalized': -5.574593544006348, 'soot_normalized': 0.11598623543977737}
# Raw:  {'pm10': 24.5, 'no2': 24.75, 'so2': 10.45, 'soot': 20.32}
# Transformed: {'no2_normalized': -7.927982330322266, 'pm10_normalized': 0.06689555943012238, 'so2_normalized': -5.074593544006348, 'soot_normalized': 0.14087554812431335}
# Raw:  {'pm10': 23.67, 'no2': 27.88, 'so2': 11.75, 'soot': 22.53}
# Transformed: {'no2_normalized': -4.797983169555664, 'pm10_normalized': 0.06383135914802551, 'so2_normalized': -3.7745933532714844, 'soot_normalized': 0.16261683404445648}
# Raw:  {'pm10': 25.67, 'no2': 29.0, 'so2': 12.4, 'soot': 20.89}
# Transformed: {'no2_normalized': -3.6779823303222656, 'pm10_normalized': 0.07121498137712479, 'so2_normalized': -3.124593734741211, 'soot_normalized': 0.14648301899433136}
# Raw:  {'pm10': 25.5, 'no2': 26.94, 'so2': 12.65, 'soot': 21.11}
# Transformed: {'no2_normalized': -5.737981796264648, 'pm10_normalized': 0.07058736681938171, 'so2_normalized': -2.874593734741211, 'soot_normalized': 0.14864732325077057}
# Raw:  {'pm10': 16.67, 'no2': 23.5, 'so2': 10.75, 'soot': 19.11}
# Transformed: {'no2_normalized': -9.177982330322266, 'pm10_normalized': 0.037988703697919846, 'so2_normalized': -4.774593353271484, 'soot_normalized': 0.12897196412086487}
# Raw:  {'pm10': 31.5, 'no2': 28.31, 'so2': 12.7, 'soot': 19.44}
# Transformed: {'no2_normalized': -4.367982864379883, 'pm10_normalized': 0.09273821115493774, 'so2_normalized': -2.8245935440063477, 'soot_normalized': 0.1322184056043625}
# Raw:  {'pm10': 31.67, 'no2': 25.73, 'so2': 10.85, 'soot': 19.65}
# Transformed: {'no2_normalized': -6.9479827880859375, 'pm10_normalized': 0.09336582571268082, 'so2_normalized': -4.674592971801758, 'soot_normalized': 0.13428430259227753}
# Raw:  {'pm10': 26.67, 'no2': 20.07, 'so2': 9.2, 'soot': 18.0}
# Transformed: {'no2_normalized': -12.607982635498047, 'pm10_normalized': 0.07490678876638412, 'so2_normalized': -6.324593544006348, 'soot_normalized': 0.11805213987827301}
# Raw:  {'pm10': 10.0, 'no2': 19.87, 'so2': 9.65, 'soot': 16.41}
# Transformed: {'no2_normalized': -12.807981491088867, 'pm10_normalized': 0.013364343903958797, 'so2_normalized': -5.874593734741211, 'soot_normalized': 0.102410227060318}
# Raw:  {'pm10': 11.83, 'no2': 20.73, 'so2': 9.8, 'soot': 18.56}
# Transformed: {'no2_normalized': -11.947982788085938, 'pm10_normalized': 0.020120352506637573, 'so2_normalized': -5.724593162536621, 'soot_normalized': 0.12356123328208923}
# Raw:  {'pm10': 23.67, 'no2': 25.0, 'so2': 11.9, 'soot': 17.67}
# Transformed: {'no2_normalized': -7.677982330322266, 'pm10_normalized': 0.06383135914802551, 'so2_normalized': -3.624593734741211, 'soot_normalized': 0.11480570584535599}
# Raw:  {'pm10': 20.33, 'no2': 24.33, 'so2': 10.85, 'soot': 16.72}
# Transformed: {'no2_normalized': -8.347982406616211, 'pm10_normalized': 0.05150071904063225, 'so2_normalized': -4.674592971801758, 'soot_normalized': 0.10545990616083145}
# Raw:  {'pm10': 18.67, 'no2': 21.73, 'so2': 11.0, 'soot': 13.61}
# Transformed: {'no2_normalized': -10.947982788085938, 'pm10_normalized': 0.04537231847643852, 'so2_normalized': -4.524593353271484, 'soot_normalized': 0.07486473023891449}
# Raw:  {'pm10': 20.33, 'no2': 22.87, 'so2': 11.5, 'soot': 18.78}
# Transformed: {'no2_normalized': -9.807981491088867, 'pm10_normalized': 0.05150071904063225, 'so2_normalized': -4.024593353271484, 'soot_normalized': 0.12572553753852844}
# Raw:  {'pm10': 32.5, 'no2': 22.0, 'so2': 10.45, 'soot': 20.0}
# Transformed: {'no2_normalized': -10.677982330322266, 'pm10_normalized': 0.09643001854419708, 'so2_normalized': -5.074593544006348, 'soot_normalized': 0.1377274990081787}
# Raw:  {'pm10': 33.25, 'no2': 24.93, 'so2': 10.8, 'soot': 22.56}
# Transformed: {'no2_normalized': -7.747982025146484, 'pm10_normalized': 0.09919887781143188, 'so2_normalized': -4.724593162536621, 'soot_normalized': 0.16291195154190063}
# Raw:  {'pm10': 26.5, 'no2': 22.6, 'so2': 10.5, 'soot': 19.11}
# Transformed: {'no2_normalized': -10.077981948852539, 'pm10_normalized': 0.07427917420864105, 'so2_normalized': -5.024593353271484, 'soot_normalized': 0.12897196412086487}
# Raw:  {'pm10': 29.25, 'no2': 26.6, 'so2': 10.3, 'soot': 23.28}
# Transformed: {'no2_normalized': -6.077981948852539, 'pm10_normalized': 0.08443164080381393, 'so2_normalized': -5.224593162536621, 'soot_normalized': 0.16999508440494537}
# Raw:  {'pm10': 33.9, 'no2': 25.69, 'so2': 10.28, 'soot': 26.33}
# Transformed: {'no2_normalized': -6.987981796264648, 'pm10_normalized': 0.10159855335950851, 'so2_normalized': -5.244593620300293, 'soot_normalized': 0.20000000298023224}
# Raw:  {'pm10': 40.03, 'no2': 28.76, 'so2': 10.28, 'soot': 29.17}
# Transformed: {'no2_normalized': -3.9179821014404297, 'pm10_normalized': 0.1242293268442154, 'so2_normalized': -5.244593620300293, 'soot_normalized': 0.22793900966644287}
# Raw:  {'pm10': 38.77, 'no2': 28.01, 'so2': 10.72, 'soot': 23.17}
# Transformed: {'no2_normalized': -4.66798210144043, 'pm10_normalized': 0.11957765370607376, 'so2_normalized': -4.804593086242676, 'soot_normalized': 0.16891293227672577}
# Raw:  {'pm10': 33.68, 'no2': 21.45, 'so2': 9.28, 'soot': 19.89}
# Transformed: {'no2_normalized': -11.227981567382812, 'pm10_normalized': 0.10078635066747665, 'so2_normalized': -6.244593620300293, 'soot_normalized': 0.1366453468799591}
# Raw:  {'pm10': 26.18, 'no2': 18.79, 'so2': 9.35, 'soot': 16.83}
# Transformed: {'no2_normalized': -13.887981414794922, 'pm10_normalized': 0.07309779524803162, 'so2_normalized': -6.174592971801758, 'soot_normalized': 0.10654205083847046}
# Raw:  {'pm10': 31.15, 'no2': 28.15, 'so2': 9.67, 'soot': 25.11}
# Transformed: {'no2_normalized': -4.527982711791992, 'pm10_normalized': 0.09144608676433563, 'so2_normalized': -5.854593276977539, 'soot_normalized': 0.18799804151058197}
# Raw:  {'pm10': 32.42, 'no2': 26.43, 'so2': 11.57, 'soot': 23.28}
# Transformed: {'no2_normalized': -6.247982025146484, 'pm10_normalized': 0.09613467007875443, 'so2_normalized': -3.9545936584472656, 'soot_normalized': 0.16999508440494537}
# Raw:  {'pm10': 24.1, 'no2': 23.91, 'so2': 9.83, 'soot': 17.06}
# Transformed: {'no2_normalized': -8.767982482910156, 'pm10_normalized': 0.06541883945465088, 'so2_normalized': -5.69459342956543, 'soot_normalized': 0.10880471765995026}
# Raw:  {'pm10': 21.87, 'no2': 24.86, 'so2': 9.44, 'soot': 25.06}
# Transformed: {'no2_normalized': -7.817981719970703, 'pm10_normalized': 0.05718610808253288, 'so2_normalized': -6.084593772888184, 'soot_normalized': 0.18750613927841187}
# Raw:  {'pm10': 25.8, 'no2': 24.5, 'so2': 10.49, 'soot': 19.95}
# Transformed: {'no2_normalized': -8.177982330322266, 'pm10_normalized': 0.07169490307569504, 'so2_normalized': -5.03459358215332, 'soot_normalized': 0.1372356116771698}
# Raw:  {'pm10': 15.02, 'no2': 18.2, 'so2': 9.03, 'soot': 13.16}
# Transformed: {'no2_normalized': -14.477981567382812, 'pm10_normalized': 0.03189722076058388, 'so2_normalized': -6.494593620300293, 'soot_normalized': 0.07043777406215668}
# Raw:  {'pm10': 16.43, 'no2': 17.79, 'so2': 9.07, 'soot': 16.21}
# Transformed: {'no2_normalized': -14.887981414794922, 'pm10_normalized': 0.03710266947746277, 'so2_normalized': -6.454593658447266, 'soot_normalized': 0.10044268518686295}
# Raw:  {'pm10': 23.88, 'no2': 25.64, 'so2': 10.05, 'soot': 21.84}
# Transformed: {'no2_normalized': -7.037982940673828, 'pm10_normalized': 0.06460663676261902, 'so2_normalized': -5.474593162536621, 'soot_normalized': 0.1558288186788559}
# Raw:  {'pm10': 32.32, 'no2': 28.14, 'so2': 10.79, 'soot': 23.05}
# Transformed: {'no2_normalized': -4.537982940673828, 'pm10_normalized': 0.09576549381017685, 'so2_normalized': -4.734593391418457, 'soot_normalized': 0.16773240268230438}
# Raw:  {'pm10': 43.03, 'no2': 27.55, 'so2': 12.89, 'soot': 28.28}
# Transformed: {'no2_normalized': -5.127983093261719, 'pm10_normalized': 0.1353047490119934, 'so2_normalized': -2.6345930099487305, 'soot_normalized': 0.21918347477912903}
# Raw:  {'pm10': 45.87, 'no2': 31.64, 'so2': 12.04, 'soot': 23.56}
# Transformed: {'no2_normalized': -1.0379829406738281, 'pm10_normalized': 0.1457894891500473, 'so2_normalized': -3.484593391418457, 'soot_normalized': 0.1727496236562729}
# Raw:  {'pm10': 40.35, 'no2': 27.91, 'so2': 11.48, 'soot': 19.67}
# Transformed: {'no2_normalized': -4.767982482910156, 'pm10_normalized': 0.12541070580482483, 'so2_normalized': -4.044593811035156, 'soot_normalized': 0.1344810575246811}
# Raw:  {'pm10': 43.2, 'no2': 21.54, 'so2': 10.99, 'soot': 12.17}
# Transformed: {'no2_normalized': -11.137981414794922, 'pm10_normalized': 0.13593237102031708, 'so2_normalized': -4.53459358215332, 'soot_normalized': 0.06069847568869591}
# Raw:  {'pm10': 30.17, 'no2': 19.47, 'so2': 9.78, 'soot': 12.44}
# Transformed: {'no2_normalized': -13.207983016967773, 'pm10_normalized': 0.08782811462879181, 'so2_normalized': -5.744593620300293, 'soot_normalized': 0.06335464119911194}
# ...
# Raw:  {'pm10': 25.95, 'no2': 36.62, 'so2': 10.09, 'soot': 13.38}
# Transformed: {'no2_normalized': 3.9420166015625, 'pm10_normalized': 0.0722486823797226, 'so2_normalized': -5.434593200683594, 'soot_normalized': 0.07260206341743469}
# Raw:  {'pm10': 21.2, 'no2': 33.32, 'so2': 10.04, 'soot': 14.46}
# Transformed: {'no2_normalized': 0.6420173645019531, 'pm10_normalized': 0.05471259728074074, 'so2_normalized': -5.484593391418457, 'soot_normalized': 0.0832267552614212}
# Raw:  {'pm10': 25.2, 'no2': 35.54, 'so2': 15.39, 'soot': 14.41}
# Transformed: {'no2_normalized': 2.862018585205078, 'pm10_normalized': 0.06947982311248779, 'so2_normalized': -0.13459300994873047, 'soot_normalized': 0.08273487538099289}
# Raw:  {'pm10': 21.73, 'no2': 30.34, 'so2': 14.31, 'soot': 15.31}
# Transformed: {'no2_normalized': -2.337982177734375, 'pm10_normalized': 0.05666925013065338, 'so2_normalized': -1.2145929336547852, 'soot_normalized': 0.09158878773450851}
# Raw:  {'pm10': 19.0, 'no2': 29.7, 'so2': 11.03, 'soot': 13.63}
# Transformed: {'no2_normalized': -2.9779815673828125, 'pm10_normalized': 0.046590615063905716, 'so2_normalized': -4.494593620300293, 'soot_normalized': 0.07506148517131805}
# Raw:  {'pm10': 38.15, 'no2': 37.31, 'so2': 15.98, 'soot': 17.72}
# Transformed: {'no2_normalized': 4.63201904296875, 'pm10_normalized': 0.117288738489151, 'so2_normalized': 0.45540618896484375, 'soot_normalized': 0.1152975782752037}
# Raw:  {'pm10': 44.1, 'no2': 39.72, 'so2': 18.52, 'soot': 16.19}
# Transformed: {'no2_normalized': 7.042018890380859, 'pm10_normalized': 0.13925498723983765, 'so2_normalized': 2.9954071044921875, 'soot_normalized': 0.10024594515562057}
# Raw:  {'pm10': 48.13, 'no2': 34.53, 'so2': 15.38, 'soot': 17.83}
# Transformed: {'no2_normalized': 1.8520164489746094, 'pm10_normalized': 0.15413297712802887, 'so2_normalized': -0.1445932388305664, 'soot_normalized': 0.11637973040342331}
# Raw:  {'pm10': 80.6, 'no2': 35.09, 'so2': 15.05, 'soot': 21.1}
# Transformed: {'no2_normalized': 2.412017822265625, 'pm10_normalized': 0.2740059792995453, 'so2_normalized': -0.4745931625366211, 'soot_normalized': 0.1485489457845688}
# Raw:  {'pm10': 76.83, 'no2': 48.86, 'so2': 18.59, 'soot': 22.71}
# Transformed: {'no2_normalized': 16.182018280029297, 'pm10_normalized': 0.26008787751197815, 'so2_normalized': 3.0654067993164062, 'soot_normalized': 0.16438759863376617}
# Raw:  {'pm10': 63.58, 'no2': 50.83, 'so2': 18.2, 'soot': 20.75}
# Transformed: {'no2_normalized': 18.152019500732422, 'pm10_normalized': 0.21117141842842102, 'so2_normalized': 2.6754074096679688, 'soot_normalized': 0.1451057493686676}
# Raw:  {'pm10': 76.58, 'no2': 49.24, 'so2': 17.4, 'soot': 24.63}
# Transformed: {'no2_normalized': 16.56201934814453, 'pm10_normalized': 0.2591649293899536, 'so2_normalized': 1.875406265258789, 'soot_normalized': 0.18327593803405762}
# Raw:  {'pm10': 48.1, 'no2': 33.23, 'so2': 16.24, 'soot': 20.34}
# Transformed: {'no2_normalized': 0.5520172119140625, 'pm10_normalized': 0.154022216796875, 'so2_normalized': 0.7154064178466797, 'soot_normalized': 0.14107230305671692}
# Raw:  {'pm10': 41.7, 'no2': 42.15, 'so2': 12.81, 'soot': 19.26}
# Transformed: {'no2_normalized': 9.47201919555664, 'pm10_normalized': 0.13039465248584747, 'so2_normalized': -2.714592933654785, 'soot_normalized': 0.1304476112127304}
# Raw:  {'pm10': 39.53, 'no2': 33.64, 'so2': 10.92, 'soot': 16.76}
# Transformed: {'no2_normalized': 0.9620170593261719, 'pm10_normalized': 0.12238342314958572, 'so2_normalized': -4.604593276977539, 'soot_normalized': 0.10585341602563858}
# Raw:  {'pm10': 43.15, 'no2': 31.27, 'so2': 7.78, 'soot': 16.78}
# Transformed: {'no2_normalized': -1.4079818725585938, 'pm10_normalized': 0.1357477754354477, 'so2_normalized': -7.744593143463135, 'soot_normalized': 0.10605017840862274}
# Raw:  {'pm10': 37.75, 'no2': 35.07, 'so2': 9.93, 'soot': 16.31}
# Transformed: {'no2_normalized': 2.392017364501953, 'pm10_normalized': 0.11581201106309891, 'so2_normalized': -5.594593048095703, 'soot_normalized': 0.10142645984888077}
# Raw:  {'pm10': 48.85, 'no2': 35.01, 'so2': 10.1, 'soot': 13.81}
# Transformed: {'no2_normalized': 2.3320159912109375, 'pm10_normalized': 0.1567910760641098, 'so2_normalized': -5.424592971801758, 'soot_normalized': 0.07683227211236954}
# Raw:  {'pm10': 49.2, 'no2': 42.74, 'so2': 11.7, 'soot': 15.83}
# Transformed: {'no2_normalized': 10.062019348144531, 'pm10_normalized': 0.1580832153558731, 'so2_normalized': -3.8245935440063477, 'soot_normalized': 0.0967043787240982}
# Raw:  {'pm10': 49.65, 'no2': 44.01, 'so2': 12.48, 'soot': 18.78}
# Transformed: {'no2_normalized': 11.332015991210938, 'pm10_normalized': 0.159744530916214, 'so2_normalized': -3.0445938110351562, 'soot_normalized': 0.12572553753852844}
# Raw:  {'pm10': 35.98, 'no2': 33.62, 'so2': 10.33, 'soot': 17.32}
# Transformed: {'no2_normalized': 0.9420166015625, 'pm10_normalized': 0.10927750915288925, 'so2_normalized': -5.19459342956543, 'soot_normalized': 0.1113625168800354}
# Raw:  {'pm10': 31.35, 'no2': 27.43, 'so2': 12.98, 'soot': 16.06}
# Transformed: {'no2_normalized': -5.247982025146484, 'pm10_normalized': 0.09218444675207138, 'so2_normalized': -2.5445938110351562, 'soot_normalized': 0.0989670380949974}
# Raw:  {'pm10': 37.8, 'no2': 28.23, 'so2': 10.92, 'soot': 13.54}
# Transformed: {'no2_normalized': -4.4479827880859375, 'pm10_normalized': 0.1159965991973877, 'so2_normalized': -4.604593276977539, 'soot_normalized': 0.07417609542608261}
# Raw:  {'pm10': 32.88, 'no2': 34.86, 'so2': 11.08, 'soot': 10.47}
# Transformed: {'no2_normalized': 2.182018280029297, 'pm10_normalized': 0.09783291071653366, 'so2_normalized': -4.44459342956543, 'soot_normalized': 0.04397442564368248}
# Raw:  {'pm10': 30.68, 'no2': 27.07, 'so2': 9.95, 'soot': 11.03}
# Transformed: {'no2_normalized': -5.607982635498047, 'pm10_normalized': 0.08971092849969864, 'so2_normalized': -5.574593544006348, 'soot_normalized': 0.0494835190474987}
# Raw:  {'pm10': 27.85, 'no2': 23.1, 'so2': 12.35, 'soot': 11.38}
# Transformed: {'no2_normalized': -9.577981948852539, 'pm10_normalized': 0.0792631208896637, 'so2_normalized': -3.174592971801758, 'soot_normalized': 0.05292670801281929}
# Raw:  {'pm10': 32.95, 'no2': 27.42, 'so2': 12.55, 'soot': 11.92}
# Transformed: {'no2_normalized': -5.25798225402832, 'pm10_normalized': 0.09809133410453796, 'so2_normalized': -2.974593162536621, 'soot_normalized': 0.058239053934812546}
# Raw:  {'pm10': 22.08, 'no2': 30.36, 'so2': 12.02, 'soot': 10.5}
# Transformed: {'no2_normalized': -2.317981719970703, 'pm10_normalized': 0.05796138569712639, 'so2_normalized': -3.5045928955078125, 'soot_normalized': 0.04426955059170723}
# Raw:  {'pm10': 32.73, 'no2': 35.57, 'so2': 14.79, 'soot': 12.7}
# Transformed: {'no2_normalized': 2.892017364501953, 'pm10_normalized': 0.0972791314125061, 'so2_normalized': -0.734593391418457, 'soot_normalized': 0.06591244041919708}
# Raw:  {'pm10': 28.98, 'no2': 30.92, 'so2': 14.07, 'soot': 13.15}
# Transformed: {'no2_normalized': -1.7579822540283203, 'pm10_normalized': 0.08343485742807388, 'so2_normalized': -1.4545936584472656, 'soot_normalized': 0.0703393965959549}
# Raw:  {'pm10': 42.05, 'no2': 34.51, 'so2': 15.36, 'soot': 13.18}
# Transformed: {'no2_normalized': 1.8320159912109375, 'pm10_normalized': 0.13168677687644958, 'so2_normalized': -0.16459369659423828, 'soot_normalized': 0.07063452899456024}
# Raw:  {'pm10': 58.78, 'no2': 45.75, 'so2': 14.98, 'soot': 22.3}
# Transformed: {'no2_normalized': 13.072017669677734, 'pm10_normalized': 0.19345073401927948, 'so2_normalized': -0.5445938110351562, 'soot_normalized': 0.1603541523218155}
# Raw:  {'pm10': 63.48, 'no2': 51.06, 'so2': 15.23, 'soot': 25.33}
# Transformed: {'no2_normalized': 18.38201904296875, 'pm10_normalized': 0.21080222725868225, 'so2_normalized': -0.29459381103515625, 'soot_normalized': 0.1901623159646988}
# Raw:  {'pm10': 57.1, 'no2': 42.83, 'so2': 15.44, 'soot': 27.76}
# Transformed: {'no2_normalized': 10.152019500732422, 'pm10_normalized': 0.18724848330020905, 'so2_normalized': -0.0845937728881836, 'soot_normalized': 0.21406787633895874}
# Raw:  {'pm10': 34.05, 'no2': 38.46, 'so2': 13.78, 'soot': 19.68}
# Transformed: {'no2_normalized': 5.782016754150391, 'pm10_normalized': 0.10215231776237488, 'so2_normalized': -1.744593620300293, 'soot_normalized': 0.13457943499088287}
# Raw:  {'pm10': 36.8, 'no2': 40.8, 'so2': 13.79, 'soot': 18.8}
# Transformed: {'no2_normalized': 8.122016906738281, 'pm10_normalized': 0.11230479180812836, 'so2_normalized': -1.734593391418457, 'soot_normalized': 0.1259222775697708}
# Raw:  {'pm10': 35.15, 'no2': 34.6, 'so2': 12.44, 'soot': 18.1}
# Transformed: {'no2_normalized': 1.9220161437988281, 'pm10_normalized': 0.10621331632137299, 'so2_normalized': -3.0845937728881836, 'soot_normalized': 0.11903590708971024}
# Raw:  {'pm10': 49.28, 'no2': 39.76, 'so2': 16.46, 'soot': 18.62}
# Transformed: {'no2_normalized': 7.0820159912109375, 'pm10_normalized': 0.15837855637073517, 'so2_normalized': 0.9354057312011719, 'soot_normalized': 0.12415150552988052}
# Raw:  {'pm10': 66.23, 'no2': 38.92, 'so2': 15.99, 'soot': 24.0}
# Transformed: {'no2_normalized': 6.242015838623047, 'pm10_normalized': 0.22095471620559692, 'so2_normalized': 0.4654064178466797, 'soot_normalized': 0.17707820236682892}
# Raw:  {'pm10': 51.9, 'no2': 29.95, 'so2': 12.58, 'soot': 17.11}
# Transformed: {'no2_normalized': -2.7279815673828125, 'pm10_normalized': 0.1680510938167572, 'so2_normalized': -2.9445934295654297, 'soot_normalized': 0.10929661244153976}
# Raw:  {'pm10': 41.4, 'no2': 20.78, 'so2': 16.75, 'soot': 16.29}
# Transformed: {'no2_normalized': -11.897981643676758, 'pm10_normalized': 0.12928710877895355, 'so2_normalized': 1.2254066467285156, 'soot_normalized': 0.1012297198176384}
# Raw:  {'pm10': 26.83, 'no2': 26.44, 'so2': 15.29, 'soot': 11.27}
# Transformed: {'no2_normalized': -6.237981796264648, 'pm10_normalized': 0.07549747824668884, 'so2_normalized': -0.23459339141845703, 'soot_normalized': 0.05184456706047058}
# Raw:  {'pm10': 22.47, 'no2': 26.38, 'so2': 16.08, 'soot': 8.19}
# Transformed: {'no2_normalized': -6.297983169555664, 'pm10_normalized': 0.059401191771030426, 'so2_normalized': 0.5554065704345703, 'soot_normalized': 0.02154451049864292}
# Raw:  {'pm10': 17.87, 'no2': 27.9, 'so2': 16.79, 'soot': 9.55}
# Transformed: {'no2_normalized': -4.777982711791992, 'pm10_normalized': 0.04241887480020523, 'so2_normalized': 1.2654075622558594, 'soot_normalized': 0.03492375835776329}
# Raw:  {'pm10': 21.73, 'no2': 27.23, 'so2': 18.79, 'soot': 8.49}
# Transformed: {'no2_normalized': -5.4479827880859375, 'pm10_normalized': 0.05666925013065338, 'so2_normalized': 3.2654075622558594, 'soot_normalized': 0.024495815858244896}
# Raw:  {'pm10': 22.07, 'no2': 27.29, 'so2': 14.36, 'soot': 11.04}
# Transformed: {'no2_normalized': -5.387981414794922, 'pm10_normalized': 0.05792446434497833, 'so2_normalized': -1.1645936965942383, 'soot_normalized': 0.049581896513700485}
# Raw:  {'pm10': 53.3, 'no2': 34.32, 'so2': 15.87, 'soot': 12.51}
# Transformed: {'no2_normalized': 1.6420173645019531, 'pm10_normalized': 0.17321962118148804, 'so2_normalized': 0.34540653228759766, 'soot_normalized': 0.06404328346252441}
# Raw:  {'pm10': 72.27, 'no2': 32.79, 'so2': 19.79, 'soot': 14.8}
# Transformed: {'no2_normalized': 0.11201858520507812, 'pm10_normalized': 0.2432532161474228, 'so2_normalized': 4.265407562255859, 'soot_normalized': 0.08657156676054001}
# Raw:  {'pm10': 35.07, 'no2': 25.75, 'so2': 15.19, 'soot': 12.5}
# Transformed: {'no2_normalized': -6.927982330322266, 'pm10_normalized': 0.10591796785593033, 'so2_normalized': -0.3345937728881836, 'soot_normalized': 0.06394490599632263}
# Raw:  {'pm10': 30.7, 'no2': 33.26, 'so2': 14.51, 'soot': 14.18}
# Transformed: {'no2_normalized': 0.5820159912109375, 'pm10_normalized': 0.08978477120399475, 'so2_normalized': -1.0145931243896484, 'soot_normalized': 0.08047220855951309}
# Raw:  {'pm10': 59.2, 'no2': 37.4, 'so2': 27.18, 'soot': 20.77}
# Transformed: {'no2_normalized': 4.722019195556641, 'pm10_normalized': 0.1950012892484665, 'so2_normalized': 11.655406951904297, 'soot_normalized': 0.14530250430107117}
# Raw:  {'pm10': 89.33, 'no2': 47.61, 'so2': 23.2, 'soot': 25.04}
# Transformed: {'no2_normalized': 14.932018280029297, 'pm10_normalized': 0.30623549222946167, 'so2_normalized': 7.675407409667969, 'soot_normalized': 0.1873093992471695}
# Raw:  {'pm10': 78.7, 'no2': 55.61, 'so2': 21.38, 'soot': 27.87}
# Transformed: {'no2_normalized': 22.932018280029297, 'pm10_normalized': 0.2669915556907654, 'so2_normalized': 5.855405807495117, 'soot_normalized': 0.21515002846717834}
# Raw:  {'pm10': 177.1, 'no2': 85.79, 'so2': 23.24, 'soot': 36.75}
# Transformed: {'no2_normalized': 53.11201858520508, 'pm10_normalized': 0.630265474319458, 'so2_normalized': 7.71540641784668, 'soot_normalized': 0.3025085926055908}
# Raw:  {'pm10': 190.23, 'no2': 89.32, 'so2': 25.1, 'soot': 34.97}
# Transformed: {'no2_normalized': 56.64201736450195, 'pm10_normalized': 0.6787388324737549, 'so2_normalized': 9.575407028198242, 'soot_normalized': 0.2849975526332855}
# Raw:  {'pm10': 142.83, 'no2': 58.59, 'so2': 21.36, 'soot': 23.35}
# Transformed: {'no2_normalized': 25.912017822265625, 'pm10_normalized': 0.5037471652030945, 'so2_normalized': 5.835407257080078, 'soot_normalized': 0.17068372666835785}
# Raw:  {'pm10': 88.77, 'no2': 42.78, 'so2': 19.86, 'soot': 23.85}
# Transformed: {'no2_normalized': 10.10201644897461, 'pm10_normalized': 0.30416804552078247, 'so2_normalized': 4.335407257080078, 'soot_normalized': 0.17560255527496338}
# Raw:  {'pm10': 63.73, 'no2': 52.96, 'so2': 19.28, 'soot': 26.09}
# Transformed: {'no2_normalized': 20.28201675415039, 'pm10_normalized': 0.2117251753807068, 'so2_normalized': 3.7554073333740234, 'soot_normalized': 0.19763895869255066}
# Raw:  {'pm10': 114.83, 'no2': 82.11, 'so2': 25.87, 'soot': 29.71}
# Transformed: {'no2_normalized': 49.4320182800293, 'pm10_normalized': 0.4003765881061554, 'so2_normalized': 10.345407485961914, 'soot_normalized': 0.23325133323669434}
# Raw:  {'pm10': 75.4, 'no2': 61.62, 'so2': 20.27, 'soot': 24.95}
# Transformed: {'no2_normalized': 28.9420166015625, 'pm10_normalized': 0.25480860471725464, 'so2_normalized': 4.7454071044921875, 'soot_normalized': 0.18642400205135345}
# Raw:  {'pm10': 67.47, 'no2': 39.94, 'so2': 19.6, 'soot': 19.67}
# Transformed: {'no2_normalized': 7.262016296386719, 'pm10_normalized': 0.22553254663944244, 'so2_normalized': 4.075407028198242, 'soot_normalized': 0.1344810575246811}
# Raw:  {'pm10': 62.93, 'no2': 71.05, 'so2': 25.36, 'soot': 19.86}
# Transformed: {'no2_normalized': 38.37202072143555, 'pm10_normalized': 0.2087717354297638, 'so2_normalized': 9.835407257080078, 'soot_normalized': 0.13635022938251495}
# Raw:  {'pm10': 114.03, 'no2': 86.51, 'so2': 30.76, 'soot': 29.9}
# Transformed: {'no2_normalized': 53.8320198059082, 'pm10_normalized': 0.39742311835289, 'so2_normalized': 15.235406875610352, 'soot_normalized': 0.2351205050945282}
# Raw:  {'pm10': 178.07, 'no2': 106.03, 'so2': 33.76, 'soot': 43.22}
# Transformed: {'no2_normalized': 73.35202026367188, 'pm10_normalized': 0.6338465213775635, 'so2_normalized': 18.23540496826172, 'soot_normalized': 0.3661583960056305}
# Raw:  {'pm10': 98.0, 'no2': 82.28, 'so2': 27.73, 'soot': 31.5}
# Transformed: {'no2_normalized': 49.60201644897461, 'pm10_normalized': 0.3382434546947479, 'so2_normalized': 12.205406188964844, 'soot_normalized': 0.2508607804775238}
# Raw:  {'pm10': 24.07, 'no2': 44.24, 'so2': 15.76, 'soot': 16.46}
# Transformed: {'no2_normalized': 11.562019348144531, 'pm10_normalized': 0.06530807912349701, 'so2_normalized': 0.23540687561035156, 'soot_normalized': 0.10290210694074631}
# Raw:  {'pm10': 24.03, 'no2': 42.27, 'so2': 18.57, 'soot': 14.21}
# Transformed: {'no2_normalized': 9.592018127441406, 'pm10_normalized': 0.06516041606664658, 'so2_normalized': 3.0454063415527344, 'soot_normalized': 0.08076734095811844}
# Raw:  {'pm10': 47.97, 'no2': 31.57, 'so2': 15.66, 'soot': 14.01}
# Transformed: {'no2_normalized': -1.1079826354980469, 'pm10_normalized': 0.15354229509830475, 'so2_normalized': 0.135406494140625, 'soot_normalized': 0.07879980653524399}
